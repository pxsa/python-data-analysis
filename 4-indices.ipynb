# %% [markdown]
# # Indexing & Sorting

# %%
import pandas as pd

# %%
happiness = pd.read_csv('data/world-happiness-report-2021.csv')

# %%
happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
happiness.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %%
happiness.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
happiness.tail()
# Out:
#     Country name  Regional indicator  Ladder score  \
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 144                           0.120         3.748         3.276
# 145                           0.074         3.611         3.322
# 146                           0.068         3.548         3.282
# 147                           0.058         3.259         3.030
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 144                  7.926           0.787                   48.700
# 145                  9.782           0.784                   59.269
# ...

# %%
happiness['Regional indicator'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Regional indicator'>

# %%
happiness.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
happiness.set_index('Country name', inplace=True)

# %%
happiness.head()
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland          Western Europe         7.842                           0.032
# Denmark          Western Europe         7.620                           0.035
# Switzerland      Western Europe         7.571                           0.036
# Iceland          Western Europe         7.554                           0.059
# Netherlands      Western Europe         7.464                           0.027
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904         7.780                 10.775
# Denmark              7.687         7.552                 10.933
# Switzerland          7.643         7.500                 11.117
# Iceland              7.670         7.438                 10.878
# Netherlands          7.518         7.410                 10.932
#
#               Social support  Healthy life expectancy  \
# Country name
# ...

# %%
happiness.describe().loc[['mean']]
# Out:
#       Ladder score  Standard error of ladder score  upperwhisker  \
# mean      5.532839                        0.058752      5.648007
#
#       lowerwhisker  Logged GDP per capita  Social support  \
# mean      5.417631               9.432208        0.814745
#
#       Healthy life expectancy  Freedom to make life choices  Generosity  \
# mean                64.992799                      0.791597   -0.015134
#
#       Perceptions of corruption  Ladder score in Dystopia  \
# mean                    0.72745                      2.43
#
#       Explained by: Log GDP per capita  Explained by: Social support  \
# mean                          0.977161                      0.793315
#
#       Explained by: Healthy life expectancy  \
# mean                               0.520161
#
#       Explained by: Freedom to make life choices  Explained by: Generosity  \
# mean                                    0.498711                  0.178047
#
# ...

# %%
happiness.loc[['Iran']]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Iran          Middle East and North Africa         4.721
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Iran                                   0.055         4.828         4.614
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Iran                          9.584            0.71                     66.3
#
#               Freedom to make life choices  Generosity  \
# Country name
# Iran                                 0.608       0.218
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# Iran                              0.714                      2.43
#
#               Explained by: Log GDP per capita  Explained by: Social support  \
# Country name
# Iran                                      1.03                         0.557
#
# ...

# %%
happiness["Healthy life expectancy"].head().plot(kind='barh')
# Out:
# <Axes: ylabel='Country name'>

# %%
countries = pd.read_csv('data/world-happiness-report-2021.csv', index_col=0)

# %%
countries.head()
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland          Western Europe         7.842                           0.032
# Denmark          Western Europe         7.620                           0.035
# Switzerland      Western Europe         7.571                           0.036
# Iceland          Western Europe         7.554                           0.059
# Netherlands      Western Europe         7.464                           0.027
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904         7.780                 10.775
# Denmark              7.687         7.552                 10.933
# Switzerland          7.643         7.500                 11.117
# Iceland              7.670         7.438                 10.878
# Netherlands          7.518         7.410                 10.932
#
#               Social support  Healthy life expectancy  \
# Country name
# ...

# %% [markdown]
# # Sorting

# %%
countries.sort_values('Ladder score')
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Afghanistan           South Asia         2.523
# Zimbabwe      Sub-Saharan Africa         3.145
# Rwanda        Sub-Saharan Africa         3.415
# Botswana      Sub-Saharan Africa         3.467
# Lesotho       Sub-Saharan Africa         3.512
# ...                          ...           ...
# Netherlands       Western Europe         7.464
# Iceland           Western Europe         7.554
# Switzerland       Western Europe         7.571
# Denmark           Western Europe         7.620
# Finland           Western Europe         7.842
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# Zimbabwe                               0.058         3.259         3.030
# Rwanda                                 0.068         3.548         3.282
# ...

# %%
countries.sort_values('Ladder score', ascending=False)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
houses = pd.read_csv('data/kc_house_data.csv')
titanic = pd.read_csv('data/titanic.csv')

# %%
houses.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
houses.sort_values('price', ascending=False).head(10)
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 8092  1924059029  20140617T000000  4668000.0         5       6.75
# 2626  7738500731  20140815T000000  4500000.0         5       5.50
# 8638  3835500195  20140618T000000  4489000.0         4       3.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
houses[['bedrooms', 'bathrooms']]
# Out:
#        bedrooms  bathrooms
# 0             3       1.00
# 1             3       2.25
# 2             2       1.00
# 3             4       3.00
# 4             3       2.00
# ...         ...        ...
# 21608         3       2.50
# 21609         4       2.50
# 21610         2       0.75
# 21611         3       2.50
# 21612         2       0.75
#
# [21613 rows x 2 columns]

# %%
countries.loc['Iran']
# Out:
# Regional indicator                            Middle East and North Africa
# Ladder score                                                         4.721
# Standard error of ladder score                                       0.055
# upperwhisker                                                         4.828
# lowerwhisker                                                         4.614
# Logged GDP per capita                                                9.584
# Social support                                                        0.71
# Healthy life expectancy                                               66.3
# Freedom to make life choices                                         0.608
# Generosity                                                           0.218
# Perceptions of corruption                                            0.714
# Ladder score in Dystopia                                              2.43
# ...

# %%
countries.loc[['Iran', 'United States', 'Germany']]
# Out:
#                          Regional indicator  Ladder score  \
# Country name
# Iran           Middle East and North Africa         4.721
# United States         North America and ANZ         6.951
# Germany                      Western Europe         7.155
#
#                Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Iran                                    0.055         4.828         4.614
# United States                           0.049         7.047         6.856
# Germany                                 0.040         7.232         7.077
#
#                Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Iran                           9.584           0.710                     66.3
# United States                 11.023           0.920                     68.2
# Germany                       10.873           0.903                     72.5
#
#                Freedom to make life choices  Generosity  \
# Country name
# ...

# %%
countries['Generosity'].loc['China']
# Out:
# np.float64(-0.146)

# %%
btc = pd.read_csv('data/coin_Bitcoin.csv')
btc.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
btc.set_index('Date',  inplace=True)

# %%
btc.head()
# Out:
#                      SNo     Name Symbol        High         Low        Open  \
# Date
# 2013-04-29 23:59:59    1  Bitcoin    BTC  147.488007  134.000000  134.444000
# 2013-04-30 23:59:59    2  Bitcoin    BTC  146.929993  134.050003  144.000000
# 2013-05-01 23:59:59    3  Bitcoin    BTC  139.889999  107.720001  139.000000
# 2013-05-02 23:59:59    4  Bitcoin    BTC  125.599998   92.281898  116.379997
# 2013-05-03 23:59:59    5  Bitcoin    BTC  108.127998   79.099998  106.250000
#
#                           Close  Volume     Marketcap
# Date
# 2013-04-29 23:59:59  144.539993     0.0  1.603769e+09
# 2013-04-30 23:59:59  139.000000     0.0  1.542813e+09
# 2013-05-01 23:59:59  116.989998     0.0  1.298955e+09
# 2013-05-02 23:59:59  105.209999     0.0  1.168517e+09
# 2013-05-03 23:59:59   97.750000     0.0  1.085995e+09

# %%
btc.set_index('SNo')
# Out:
#          Name Symbol          High           Low          Open         Close  \
# SNo
# 1     Bitcoin    BTC    147.488007    134.000000    134.444000    144.539993
# 2     Bitcoin    BTC    146.929993    134.050003    144.000000    139.000000
# 3     Bitcoin    BTC    139.889999    107.720001    139.000000    116.989998
# 4     Bitcoin    BTC    125.599998     92.281898    116.379997    105.209999
# 5     Bitcoin    BTC    108.127998     79.099998    106.250000     97.750000
# ...       ...    ...           ...           ...           ...           ...
# 2987  Bitcoin    BTC  33939.588699  32770.680780  33549.600177  33897.048590
# 2988  Bitcoin    BTC  34909.259899  33402.696536  33854.421362  34668.548402
# 2989  Bitcoin    BTC  35937.567147  34396.477458  34665.564866  35287.779766
# 2990  Bitcoin    BTC  35284.344430  33213.661034  35284.344430  33746.002456
# 2991  Bitcoin    BTC  35038.536363  33599.916169  33723.509655  34235.193451
#
#             Volume     Marketcap
# SNo
# ...

# %%
btc.head()
# Out:
#                      SNo     Name Symbol        High         Low        Open  \
# Date
# 2013-04-29 23:59:59    1  Bitcoin    BTC  147.488007  134.000000  134.444000
# 2013-04-30 23:59:59    2  Bitcoin    BTC  146.929993  134.050003  144.000000
# 2013-05-01 23:59:59    3  Bitcoin    BTC  139.889999  107.720001  139.000000
# 2013-05-02 23:59:59    4  Bitcoin    BTC  125.599998   92.281898  116.379997
# 2013-05-03 23:59:59    5  Bitcoin    BTC  108.127998   79.099998  106.250000
#
#                           Close  Volume     Marketcap
# Date
# 2013-04-29 23:59:59  144.539993     0.0  1.603769e+09
# 2013-04-30 23:59:59  139.000000     0.0  1.542813e+09
# 2013-05-01 23:59:59  116.989998     0.0  1.298955e+09
# 2013-05-02 23:59:59  105.209999     0.0  1.168517e+09
# 2013-05-03 23:59:59   97.750000     0.0  1.085995e+09

# %%
btc.index
# Out:
# Index(['2013-04-29 23:59:59', '2013-04-30 23:59:59', '2013-05-01 23:59:59',
#        '2013-05-02 23:59:59', '2013-05-03 23:59:59', '2013-05-04 23:59:59',
#        '2013-05-05 23:59:59', '2013-05-06 23:59:59', '2013-05-07 23:59:59',
#        '2013-05-08 23:59:59',
#        ...
#        '2021-06-27 23:59:59', '2021-06-28 23:59:59', '2021-06-29 23:59:59',
#        '2021-06-30 23:59:59', '2021-07-01 23:59:59', '2021-07-02 23:59:59',
#        '2021-07-03 23:59:59', '2021-07-04 23:59:59', '2021-07-05 23:59:59',
#        '2021-07-06 23:59:59'],
#       dtype='object', name='Date', length=2991)

# %%
btc.High
# Out:
# Date
# 2013-04-29 23:59:59      147.488007
# 2013-04-30 23:59:59      146.929993
# 2013-05-01 23:59:59      139.889999
# 2013-05-02 23:59:59      125.599998
# 2013-05-03 23:59:59      108.127998
#                            ...
# 2021-07-02 23:59:59    33939.588699
# 2021-07-03 23:59:59    34909.259899
# 2021-07-04 23:59:59    35937.567147
# 2021-07-05 23:59:59    35284.344430
# 2021-07-06 23:59:59    35038.536363
# Name: High, Length: 2991, dtype: float64

# %%
btc['High'].plot()
# Out:
# <Axes: xlabel='Date'>
